# %% [markdown]
# <a href="https://www.nvidia.com/"> <img src="images/nvidia_header.png" style="margin-left: -30px; width: 300px; float: left;"> </a>

# %% [markdown]
# # Mini Hands-On - Accelerate Drug Discovery with NVIDIA BioNeMo
#
# Copyright (c) 2026, NVIDIA CORPORATION. Licensed under the Apache License, Version 2.0 (the "License") you may not use this file except in compliance with the License. You may obtain a copy of the License at http://www.apache.org/licenses/LICENSE-2.0 Unless required by applicable law or agreed to in writing, software distributed under the License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the License for the specific language governing permissions and limitations under the License.
#
# ---
#
# This mini hands-on track is integrated into AI-Powered-Drug-Discovery-Bootcamp. It keeps a shorter guided flow while using this repository's MolMIM and Boltz-2 endpoint environment, shared CDK oracle code, and deployment workflow. On ARM64 nodes (GB200/GB300), Boltz-2 runs locally and MolMIM can also run locally via `--molmim local-arm` (a pure-PyTorch MolMIM NIM), or you can use a hosted MolMIM endpoint.
#
# Use this track when you want the compact version of the bootcamp: setup, CDK4/CDK11 design context, a guided design pipeline, and two optional deep dives. The full `tutorials/` and `challenge/` folders provide the expanded version.

# %% [markdown]
# ## Table of Contents
#
# The mini track assumes the same endpoint environment as the full bootcamp. Start with setup unless your instructor or system administrator already started or configured the NIM services and provided `.openhackathon-nims.env`.
#
# 1. [NIM Setup](01_NIM_Setup.ipynb)<br>
#     Start or verify MolMIM and Boltz-2 endpoints.
# <br>
#
# 2. [Overview - Designing CDK4 Inhibitors](02_Overview-Designing_CDK4_Inhibitors.ipynb)<br>
#     Review the CDK4 potency and CDK11 avoidance objective.
# <br>
#
# 3. [Hands-On - CDK Inhibitor Design](03_Hands-On_CDK_Inhibitor_Design.ipynb)<br>
#     Generate, score, and rank candidate molecules with the repository pipeline.
# <br>
#
# 4. [Optional - MolMIM CMA-ES Controlled Generation](04_Optional_MolMIM_CMA-ES_Controlled_Generation.ipynb)<br>
#     See how oracle-guided latent-space search works.
# <br>
#
# 5. [Optional - Boltz-2 Affinity Prediction Validation](05_Optional_Boltz2_validation.ipynb)<br>
#     Compare Boltz-2 affinity predictions for known actives and decoys.
# <br>

# %% [markdown]
# ### JupyterLab
# For this hands-on lab, we use [JupyterLab](https://jupyterlab.readthedocs.io/en/stable/) to manage our environment.  The [JupyterLab Interface](https://jupyterlab.readthedocs.io/en/stable/user/interface.html) is a dashboard that provides access to interactive iPython notebooks, as well as the folder structure of our environment and a terminal window into the Ubuntu operating system. The first view you'll see includes a **menu bar** at the top, a **file browser** in the **left sidebar**, and a **main work area** that is initially open to the "Launcher" page.
#
# <img src="images/jl_launcher.png">
#
# The file browser can be navigated just like any other file explorer. A double click on any of the items will open a new tab with its content.
#
# The main work area includes tabbed views of open files that can be closed, moved, and edited as needed.
#
# The notebooks, including this one, consist of a series of content and code **cells**.  To execute code in a code cell, press `Shift+Enter` or the "Run" button in the menu bar above, while a cell is highlighted. Sometimes, a content cell will get switched to editing mode. Pressing `Shift+Enter` will switch it back to a readable form.
#
# Try executing the simple print statement in the cell below.

# %%
# Highlight this cell and click [Shift+Enter] to execute
print('This is just a simple print statement')

# %% [markdown]
# <a href="https://www.nvidia.com/"> <img src="images/nvidia_header.png" style="margin-left: -30px; width: 300px; float: left;"> </a>
